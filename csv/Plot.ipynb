# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def readfile(p):
    x = []
    y = []
    with open(p) as f:
        f.readline()
        for line in f:
            t,step,val_acc = line.strip().split(',')
            x.append(float(t))
            y.append(float(val_acc))
    x = np.array(x)
    y = np.array(y)
    x = x - x[0]
    x = x/60
    return x,y

# %%
# !ls
# Out:
# CL-CCL-CCLL-CMCML-CMCMLL.png
# CL-CLD-CMCML-CMCMLL.png
# CL-CLL-CML-CLD.png
# CL-CM-CCM-CD.png
# CL-D-LD.png
# Plot.ipynb
# run-2-all_tboard_CCLL-tag-epoch_val_acc.csv
# run-2-all_tboard_CCL-tag-epoch_val_acc.csv
# run-2-all_tboard_CCM-tag-epoch_val_acc.csv
# run-2-all_tboard_CD-tag-epoch_val_acc.csv
# run-2-all_tboard_CLD-tag-epoch_val_acc.csv
# run-2-all_tboard_CLL-tag-epoch_val_acc.csv
# run-2-all_tboard_CL-tag-epoch_val_acc.csv
# run-2-all_tboard_CMCMLL-tag-epoch_val_acc.csv
# run-2-all_tboard_CMCML-tag-epoch_val_acc.csv
# run-2-all_tboard_CML-tag-epoch_val_acc.csv
# run-2-all_tboard_CM-tag-epoch_val_acc.csv
# run-2-all_tboard_D-tag-epoch_val_acc.csv
# run-2-all_tboard_LD-tag-epoch_val_acc.csv
# run-CCLL-tag-epoch_val_acc.csv
# run-CCL-tag-epoch_val_acc.csv
# run-CCM-tag-epoch_val_acc.csv
# run-CD-tag-epoch_val_acc.csv
# run-CLD-tag-epoch_val_acc.csv
# run-CLL-tag-epoch_val_acc.csv
# run-CL-tag-epoch_val_acc.csv
# run-CMCMLL-tag-epoch_val_acc.csv
# run-CMCML-tag-epoch_val_acc.csv
# run-CML-tag-epoch_val_acc.csv
# run-CM-tag-epoch_val_acc.csv
# run-D-tag-epoch_val_acc.csv
# run-LD-tag-epoch_val_acc.csv

# %%
x,y = readfile('./run-CL-tag-epoch_val_acc.csv')

# %%
plt.plot(x,y,'o')
plt.grid()

# %%
a = !ls run*
[y for y in [x.split('-')[1] for x in a] if y != '2']
# Out:
# ['CCLL',
#  'CCL',
#  'CCM',
#  'CD',
#  'CLD',
#  'CLL',
#  'CL',
#  'CMCMLL',
#  'CMCML',
#  'CML',
#  'CM',
#  'D',
#  'LD']

# %%
exps = ['CCLL', 'CCL', 'CCM', 'CD', 'CLD', 'CLL', 'CL', 'CMCMLL', 'CMCML', 'CML', 'CM', 'D', 'LD']

# %%
data = {}
for e in exps:
    data[e] = readfile('run-' + e + '-tag-epoch_val_acc.csv')

# %%
def plot(experiments):
    fig = plt.figure(figsize=(12,8))
    for i,j in zip(experiments, ['--k', '-bx', '-g+', '-r*', '-mD']):
        plt.plot(*data[i], j, label=i)
    plt.ylim((0.32, 0.92))
    plt.xlim((-0.2, 10.5))
    plt.legend(loc='lower right')
    plt.grid()
    plt.savefig('-'.join(experiments)+'.png')
    plt.show()

# %%
plot(['CL', 'D', 'LD'])

# %%
plot(['CL', 'CLL', 'CML', 'CLD'])

# %%
plot(['CL', 'CM', 'CCM', 'CD'])

# %%
plot(['CL', 'CCL', 'CCLL', 'CMCML', 'CMCMLL'])

# %%
plot(['CL', 'CLD', 'CMCML', 'CMCMLL'])

# %%
data['LD']
# Out:
# (array([ 0.        ,  1.04625243,  2.10087534,  3.15572859,  4.21191167,
#          5.26537708,  6.31663361,  7.3678874 ,  8.41979456,  9.47613535]),
#  array([ 0.40799999,  0.43700001,  0.44800001,  0.44499999,  0.44100001,
#          0.41100001,  0.43000001,  0.414     ,  0.454     ,  0.36500001]))
